# %%
import pandas as pd

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# df['koi_disposition']=df['koi_disposition'].map({'CANDIDATE':2,'CONFIRMED':1,'FALSE POSITIVE':0})
# df
y=df.pop('koi_disposition')
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
df
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
# ...

# %%
encoded_y
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
from sklearn.model_selection import train_test_split # to split the data into two parts
train_x,test_x,train_y,test_y = train_test_split(df, encoded_y,test_size = 0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier # for random forest classifier
model=RandomForestClassifier(n_estimators=100)
model.fit(train_x,train_y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
prediction=model.predict(test_x)

# %%
from sklearn import metrics # for the check the error and accuracy of the model
metrics.accuracy_score(prediction,test_y)
# Out:
# 0.8963545389563974

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = model.feature_importances_
importances
# Out:
# array([0.09378708, 0.0716993 , 0.10421438, 0.03568383, 0.02088895,
#        0.01872973, 0.01698007, 0.01315249, 0.02206226, 0.020461  ,
#        0.01859198, 0.01149252, 0.01190681, 0.02112907, 0.03255589,
#        0.03308253, 0.01879896, 0.01390061, 0.01153853, 0.05708529,
#        0.03718008, 0.02400939, 0.017874  , 0.01803692, 0.01969541,
#        0.01538502, 0.05625475, 0.00321012, 0.00984432, 0.0314692 ,
#        0.02845628, 0.00940652, 0.00860865, 0.00998931, 0.00951935,
#        0.01100318, 0.00802888, 0.01255775, 0.01157386, 0.01015574])

# %%
# We can sort the features by their importance
sorted(zip(model.feature_importances_, train_x.columns), reverse=True)
# Out:
# [(0.10421437579727973, 'koi_fpflag_co'),
#  (0.09378707558496266, 'koi_fpflag_nt'),
#  (0.07169929952525715, 'koi_fpflag_ss'),
#  (0.05708529065320538, 'koi_prad'),
#  (0.05625474675155612, 'koi_model_snr'),
#  (0.03718008021577194, 'koi_prad_err1'),
#  (0.035683831209847305, 'koi_fpflag_ec'),
#  (0.03308253433902009, 'koi_duration_err2'),
#  (0.0325558853959021, 'koi_duration_err1'),
#  (0.031469202805089705, 'koi_steff_err1'),
#  (0.02845627915816722, 'koi_steff_err2'),
#  (0.024009385011586098, 'koi_prad_err2'),
#  (0.022062260117594552, 'koi_time0bk_err1'),
#  (0.021129065555496398, 'koi_duration'),
#  (0.02088895072187968, 'koi_period'),
#  (0.020460998669253345, 'koi_time0bk_err2'),
#  (0.019695413547321846, 'koi_insol_err1'),
#  (0.01879896097077612, 'koi_depth'),
#  (0.01872972628399544, 'koi_period_err1'),
#  (0.01859197995759956, 'koi_impact'),
#  (0.01803692237250195, 'koi_insol'),
#  (0.017874004351349893, 'koi_teq'),
#  (0.01698007413617537, 'koi_period_err2'),
# ...
